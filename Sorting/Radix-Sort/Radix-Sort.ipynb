# %%
#radix sort doesn't handle negative integers & floating point numbers
def radix_sort(arr):
    radix_array = [[] for i in range(10)]
    max_val = max(arr)
    exp = 1
    
    while max_val // exp > 0:
        while arr:
            val = arr.pop()
            radix_index = (val // exp) % 10
            radix_array[radix_index].append(val)
                    
        for bucket in radix_array:
            while bucket:
                val = bucket.pop()
                arr.append(val)
        exp *= 10

# %%
if __name__ == "__main__":
    arr = [170, 45, 75, 90, 802, 0, 24, 2, 66, 71, 144, 543, 100]
    print(arr)
    radix_sort(arr)
    print(arr)
# Out:
# [170, 45, 75, 90, 802, 0, 24, 2, 66, 71, 144, 543, 100]
# [0, 2, 24, 45, 66, 71, 75, 90, 100, 144, 170, 543, 802]
