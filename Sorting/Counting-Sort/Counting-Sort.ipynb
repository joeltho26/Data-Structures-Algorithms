# %%
#cannot handle negative values & floating point numbers
def counting_sort(arr):
    max_val = max(arr)
    count = [0] * (max_val + 1)
    
    while arr:
        value = arr.pop(0)
        count[value] += 1
        
    for i in range(len(count)):
        while count[i]:
            arr.append(i)
            count[i] -= 1
    
    return arr

# %%
if __name__ == "__main__":
    arr = [170, 45, 75, 90, 802, 24, 0, 2, 66]
    counting_sort(arr)
    print(arr)
# Out:
# [0, 2, 24, 45, 66, 75, 90, 170, 802]
