# %%
def insert_at_beginning(numbers, to_insert):
    numbers.insert(0, to_insert)
    return numbers

def main(numbers, to_insert):
    if to_insert:
        if isinstance(to_insert, list):
            for i in to_insert:
                numbers = insert_at_beginning(numbers, i)
                print(f"Inserted element {i} at the beginning!")
        else:
           numbers = insert_at_beginning(numbers, to_insert)
           print(f"Inserted element {to_insert} at the beginning!")
    else:
        print("No values available to insert!")
    return numbers

# %%
if __name__ == "__main__":
    numbers = [17, 4, 1, 20, 17, 9, 23, 18, 34, -15, -10]
    to_insert = [4, 7, 9, 43]
    print(f"Values before insertion: {numbers}")
    numbers = main(numbers, to_insert)
    print(f"Values after insertion: {numbers}")
# Out:
# Values before insertion: [17, 4, 1, 20, 17, 9, 23, 18, 34, -15, -10]
# Inserted element 4 at the beginning!
# Inserted element 7 at the beginning!
# Inserted element 9 at the beginning!
# Inserted element 43 at the beginning!
# Values after insertion: [43, 9, 7, 4, 17, 4, 1, 20, 17, 9, 23, 18, 34, -15, -10]

# %%
numbers = [17, 4, 1, 20, 17, 9, 23, 18, 34, -15, -10]
to_insert = 33
print(f"Values before insertion: {numbers}")
numbers = main(numbers, to_insert)
print(f"Values after insertion: {numbers}")
# Out:
# Values before insertion: [17, 4, 1, 20, 17, 9, 23, 18, 34, -15, -10]
# Inserted element 33 at the beginning!
# Values after insertion: [33, 17, 4, 1, 20, 17, 9, 23, 18, 34, -15, -10]

# %%
numbers = [17, 4, 1, 20, 17, 9, 23, 18, 34, -15, -10]
to_insert = []
print(f"Values before insertion: {numbers}")
numbers = main(numbers, to_insert)
print(f"Values after insertion: {numbers}")
# Out:
# Values before insertion: [17, 4, 1, 20, 17, 9, 23, 18, 34, -15, -10]
# No values available to insert!
# Values after insertion: [17, 4, 1, 20, 17, 9, 23, 18, 34, -15, -10]

# %%
numbers = [17, 4, 1, 20, 17, 9, 23, 18, 34, -15, -10]
to_insert = None
print(f"Values before insertion: {numbers}")
numbers = main(numbers, to_insert)
print(f"Values after insertion: {numbers}")
# Out:
# Values before insertion: [17, 4, 1, 20, 17, 9, 23, 18, 34, -15, -10]
# No values available to insert!
# Values after insertion: [17, 4, 1, 20, 17, 9, 23, 18, 34, -15, -10]
