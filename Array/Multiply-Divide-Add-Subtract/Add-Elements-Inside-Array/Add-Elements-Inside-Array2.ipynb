# %%
def addition(val, add):
    return val + add

def add_array_based_on_value(numbers, add):
    return list(map(lambda x: addition(x, add), numbers))

def main(numbers, add):
    if isinstance(add, list):
        for i in add:
            print(add_array_based_on_value(numbers, i))
    else:
        print(add_array_based_on_value(numbers, add))

# %%
numbers = [1, 60, 8, 1, 89, 3, 12]
add = 2
main(numbers, add)
# Out:
# [3, 62, 10, 3, 91, 5, 14]

# %%
numbers = [1, 60, 8, 2, 89, 3, 12]
add = [2, 3, 5]
main(numbers, add)
# Out:
# [3, 62, 10, 4, 91, 5, 14]
# [4, 63, 11, 5, 92, 6, 15]
# [6, 65, 13, 7, 94, 8, 17]
