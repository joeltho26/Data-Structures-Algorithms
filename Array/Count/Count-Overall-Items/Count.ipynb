# %%
def count(values):
    if not values:
        print("Array is empty!")
    return len(values)
    
def main(numbers):
    print(count(numbers))

# %%
if __name__ == "__main__":
    numbers = [17, 4, 1, 20, 17, 9, 23, 18, 34, -15, -10]
    main(numbers)
# Out:
# 11
