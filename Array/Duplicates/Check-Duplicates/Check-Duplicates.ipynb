# %%
def check_duplicates(numbers, value):
    if value in numbers:
        count = 0
        for i in numbers:
            if i == value:
                count += 1
                
            if count > 1:
                print(f"{value} duplicates found!")
                return True
    else:
        print(f"{value} not found in array!")
        return False
    
    print(f"{value} has no duplicates!")
    return False

def main(numbers, values):
    if values or isinstance(values, int):
        if isinstance(values, list):
            for i in values:
                print(check_duplicates(numbers, i))
        else:
            print(check_duplicates(numbers, values))

# %%
if __name__ == "__main__":
    numbers = [17, 4, 1, 20, 17, 9, 23, 18, 34, -15, -10]
    values = [18, 17, 0, 2]
    main(numbers, values)
# Out:
# 18 has no duplicates!
# False
# 17 duplicates found!
# True
# 0 not found in array!
# False
# 2 not found in array!
# False

# %%
values = 0
main(numbers, values)
# Out:
# 0 not found in array!
# False

# %%
values = 18
main(numbers, values)
# Out:
# 18 has no duplicates!
# False

# %%
values = 17
main(numbers, values)
# Out:
# 17 duplicates found!
# True
