# %%
def max_area(height: list[int]) -> int:
    final = 0 
    size = len(height)
    if size > 2:
        for i in range(0,size-1):
            for j in range(size-1,i,-1):
                val = min(height[i], height[j])
                count = len(height[i:j])
                area = val * count
                if area > final:
                    final = area
                if height[i] < height[j]:
                    break
    else:
        final = min(height[0], height[1])
        
    return final

def main(height):
    print(max_area(height))

# %%
if __name__ == "__main__":
    height = [1,8,6,2,5,4,8,3,7]
    main(height)
# Out:
# 49

# %%
height = [1,1]
main(height)
# Out:
# 1

# %%
height = [2,1,3]
main(height)
# Out:
# 4

# %%
height = [1,2,1]
main(height)
# Out:
# 2

# %%
height = [8,7,2,1]
main(height)
# Out:
# 7

# %%
height = [1,8,6,2,5,4,8,25,7]
main(height)
# Out:
# 49

# %%
height = [2,3,10,5,7,8,9]
main(height)
# Out:
# 36
