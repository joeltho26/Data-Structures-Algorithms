# %%
def reverse(values):
    return values[::-1]

def main(numbers):
    print(reverse(numbers))

# %%
if __name__ == "__main__":
    numbers = [17, 4, 1, 20, 17, 9, 23, 18, 34, -15, -10]
    main(numbers)
# Out:
# [-10, -15, 34, 18, 23, 9, 17, 20, 1, 4, 17]
