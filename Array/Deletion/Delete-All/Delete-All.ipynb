# %%
def delete(numbers):
    remaining = None
    value = numbers
    del numbers
    try:
        remaining = numbers
    except NameError:
        print("The values are removed and also the object is destroyed!")
        remaining = []
    return value, remaining

def main(numbers):
    value, numbers = delete(numbers)

    print(f"The deleted values are: {value}")
    print(f"Remaining values after deletion: {numbers}")
    return numbers

# %%
if __name__ == "__main__":
    numbers = [17, 4, 1, 20, 17, 9, 23, 18, 34, -15, -10]
    print(f"Values before deletion: {numbers}")
    numbers = main(numbers)
    print(numbers)
# Out:
# Values before deletion: [17, 4, 1, 20, 17, 9, 23, 18, 34, -15, -10]
# The values are removed and also the object is destroyed!
# The deleted values are: [17, 4, 1, 20, 17, 9, 23, 18, 34, -15, -10]
# Remaining values after deletion: []
# []
