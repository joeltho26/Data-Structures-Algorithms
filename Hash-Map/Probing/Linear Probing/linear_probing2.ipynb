# %% [markdown]
# #### Hash - collision handling by Linear Probing
# Hash Fn:
# - hash(key) + i % self.MAX
#
#     + <ins>i</ins>: Iterator
#     + <ins>self.MAX</ins>: No of buckets

# %%
# Hashing - Linear Probing  

from typing import Optional

class Hash:
    def __init__(self, size):
        self.size = size
        self.container = [None] * self.size
        
    def _generate_hash_key(self, key, itr=0):
        h = 0
        for i in key:
            h += ord(i)
        return (h+itr)%self.size
    
    def __setitem__(self, key, value):
        if not self.is_full(validate=False):
            hash_key = self._generate_hash_key(key)
            if self.container[hash_key]:
                if isinstance(self.container[hash_key], tuple):
                    if len(self.container[hash_key]) == 2:
                        if self.container[hash_key][0] == key:
                            print(f"Item {self.container[hash_key]} is updated with {(key,value)} at {hash_key}!")
                            self.container[hash_key] = (key,value)
                            return
 
            for index in range(len(self.container)):
                hash_key = self._generate_hash_key(key, index+1)
                if self.container[hash_key]:
                    if isinstance(self.container[hash_key], tuple):
                        if len(self.container[hash_key]) == 2:
                            if self.container[hash_key][0] == key:
                                print(f"Item {self.container[hash_key]} is updated with {(key,value)} at {index} via linear probing!")
                                self.container[hash_key] = (key,value)
                                return
                            
            if not self.container[hash_key]:    
                print(f"Inserted item: {(key,value)} at {hash_key}!")
                self.container[hash_key] = (key,value)  
                return 
                                        
            for index, data in enumerate(self.container):
                hash_key = self._generate_hash_key(key, index+1)
                if not data:
                    print(f"Inserted item: {(key,value)} at {hash_key} via linear probing!")
                    self.container[hash_key] = (key,value)
                    return
                
    def __getitem__(self, key: str):
        if not self.is_empty(validate=False):
            hash_key = self._generate_hash_key(key)
            if self.container[hash_key]:
                if isinstance(self.container[hash_key], tuple):
                    if len(self.container[hash_key]) == 2:
                        if self.container[hash_key][0] == key:
                            print(f"Item found: {self.container[hash_key]} at {hash_key}")
                            return self.container[hash_key]
                        
            for index in range(len(self.container)):
                hash_key = self._generate_hash_key(key, index+1)
                if isinstance(self.container[hash_key], tuple):
                    if len(self.container[hash_key]) == 2:
                        if self.container[hash_key][0] == key:
                            print(f"Item found: {self.container[hash_key]} at {index} via probing!")
                            return self.container[hash_key]                       
            
            return f"No match found for {key}!"

    def __delitem__(self, key: str):
        if not self.is_empty(validate=False):
            hash_key = self._generate_hash_key(key)
            if self.container[hash_key]:
                if isinstance(self.container[hash_key], tuple):
                    if len(self.container[hash_key]) == 2:
                        if self.container[hash_key][0] == key:
                            print(f"Item deleted: {self.container[hash_key]} at {hash_key}")
                            self.container[hash_key] = None
                            return
                        
            for index in range(len(self.container)):
                hash_key = self._generate_hash_key(key, index+1)
                if isinstance(self.container[hash_key], tuple):
                    if len(self.container[hash_key]) == 2:
                        if self.container[hash_key][0] == key:
                            print(f"Item deleted: {self.container[hash_key]} at {index} via probing!")
                            self.container[hash_key] = None
                            return 
            
            print(f"No match found for {key} to delete!")               
    
    def is_empty(self, validate: Optional[bool]=True):
        if self.get_count() == 0:
            if not validate:
                print("HashMap is empty!")
                return
            return True
        return False

    def is_full(self, validate: Optional[bool]=True):
        if self.get_count() == self.size:
            if not validate:
                print("HashMap is full!")
                return
            return True
        return False

    def get_count(self):
        count = 0
        for item in self.container:
            if item:
                count += 1
        return count

# %%
if __name__ == "__main__":
    h = Hash(10)
    h['march 9'] = 90
    h['march 17'] = 30
    print(h.container)
    h['march 6'] = 40
    print(h.container)
    h['march 6'] = 45
    h['march 19'] = 10
    print(h.container)
# Out:
# Inserted item: ('march 9', 90) at 2!
# Inserted item: ('march 17', 30) at 9!
# [None, None, ('march 9', 90), None, None, None, None, None, None, ('march 17', 30)]
# Inserted item: ('march 6', 40) at 0 via linear probing!
# [('march 6', 40), None, ('march 9', 90), None, None, None, None, None, None, ('march 17', 30)]
# Item ('march 6', 40) is updated with ('march 6', 45) at 0 via linear probing!
# Inserted item: ('march 19', 10) at 1!
# [('march 6', 45), ('march 19', 10), ('march 9', 90), None, None, None, None, None, None, ('march 17', 30)]

# %%
print(h["march 17"])
print(h["march 19"])
print(h["march 6"])
print(h["march 27"])
# Out:
# Item found: ('march 17', 30) at 9
# ('march 17', 30)
# Item found: ('march 19', 10) at 1
# ('march 19', 10)
# Item found: ('march 6', 45) at 0 via probing!
# ('march 6', 45)
# No match found for march 27!

# %%
del h["march 17"]
del h["march 9"]
del h["march 9"]
print(h.container)
del h["march 6"]
print(h.container)
# Out:
# Item deleted: ('march 17', 30) at 9
# Item deleted: ('march 9', 90) at 2
# No match found for march 9 to delete!
# [('march 6', 45), ('march 19', 10), None, None, None, None, None, None, None, None]
# Item deleted: ('march 6', 45) at 0 via probing!
# [None, ('march 19', 10), None, None, None, None, None, None, None, None]

# %%
print(h.is_empty())
print(h.is_full())
print(h.get_count())
# Out:
# False
# False
# 1

# %%
del h["march 19"]
print(h.container)
# Out:
# Item deleted: ('march 19', 10) at 1
# [None, None, None, None, None, None, None, None, None, None]

# %%
print(h.is_empty())
print(h.is_full())
print(h.get_count())
# Out:
# True
# False
# 0

# %%
print(h["march 17"])
del h["march 19"]
# Out:
# HashMap is empty!
# No match found for march 17!
# HashMap is empty!
# No match found for march 19 to delete!
